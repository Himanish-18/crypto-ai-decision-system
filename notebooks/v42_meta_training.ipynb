# %% [markdown]
# # v42 Meta-Learning Demo
# Running MAML training on v41 Simulation Scenarios.

# %%
from src.rl.meta_trainer import MetaTrainer

# Init Trainer
trainer = MetaTrainer(obs_dim=8, act_dim=2)
print("Initialized MetaTrainer with MAML-PPO")

# Run Single Update
loss = trainer.meta_update()
print(f"Meta-Loss: {loss}")
